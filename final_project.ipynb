# %% [markdown]
# Oregon Income Tax Return Types
#
# Created by: Dinh Nguyen
# For Class: Data With Python

# %% [markdown]
# Cleaning Up The Data:

# %%
import pandas as pd

df_tax = pd.read_csv("oregon_income_tax.csv")

# Show missing values per column
# print(df_tax.isnull().sum())

# Option: Drop rows with any missing values
df_tax = df_tax.dropna()

# Strip leading/trailing whitespace in column names
df_tax.columns = df_tax.columns.str.strip()

# Remove exact duplicate rows
df_tax = df_tax.drop_duplicates()

# Format columns into more Python friendly style for easy use
df_tax.columns = [
    "row_id",
    "date_of_update",
    "tax_year",
    "county",
    "num_returns",
    "total_exemptions_k",
    "total_agi_k",
    "total_additions_k",
    "total_fed_subtractions_k",
    "total_other_subtractions_k",
    "total_deductions_k",
    "total_taxable_income_k",
    "total_gross_tax_k",
    "total_credits_k",
    "total_net_tax_k",
    "avg_num_exemptions",
    "avg_agi",
    "avg_additions",
    "avg_fed_subtractions",
    "avg_other_subtractions",
    "avg_deductions",
    "avg_taxable_income",
    "avg_gross_tax",
    "avg_credits",
    "avg_net_tax",
    "tax_pct_agi",
    "tax_pct_taxable_income",
    "returns_single_num",
    "returns_single_pct",
    "returns_joint_num",
    "returns_joint_pct",
    "returns_separate_num",
    "returns_separate_pct",
    "returns_head_household_num",
    "returns_head_household_pct",
    "returns_itemized_num",
    "returns_itemized_pct",
    "returns_full_year_num",
    "returns_full_year_pct",
    "returns_part_year_num",
    "returns_part_year_pct",
    "returns_nonresident_num",
    "returns_nonresident_pct",
    "full_year_returns_num",
    "full_year_agi_k",
    "full_year_wages_k",
    "full_year_dividends_interest_k",
    "full_year_business_income_k",
    "full_year_capital_gains_k",
    "full_year_taxable_pensions_k",
    "full_year_schedule_e_income_k",
    "full_year_farm_income_k",
    "full_year_other_income_k",
    "full_year_adjustments_k",
    "exception_notes"
]

# Print each column name on its own line
for col in df_tax.columns:
    print(col)
# Out:
# row_id
# date_of_update
# tax_year
# county
# num_returns
# total_exemptions_k
# total_agi_k
# total_additions_k
# total_fed_subtractions_k
# total_other_subtractions_k
# total_deductions_k
# total_taxable_income_k
# total_gross_tax_k
# total_credits_k
# total_net_tax_k
# avg_num_exemptions
# avg_agi
# avg_additions
# avg_fed_subtractions
# avg_other_subtractions
# avg_deductions
# avg_taxable_income
# avg_gross_tax
# avg_credits
# avg_net_tax
# tax_pct_agi
# tax_pct_taxable_income
# returns_single_num
# returns_single_pct
# returns_joint_num
# returns_joint_pct
# returns_separate_num
# returns_separate_pct
# returns_head_household_num
# returns_head_household_pct
# returns_itemized_num
# returns_itemized_pct
# returns_full_year_num
# returns_full_year_pct
# returns_part_year_num
# returns_part_year_pct
# returns_nonresident_num
# returns_nonresident_pct
# full_year_returns_num
# full_year_agi_k
# full_year_wages_k
# full_year_dividends_interest_k
# full_year_business_income_k
# ...
