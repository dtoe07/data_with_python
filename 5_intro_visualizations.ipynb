# %% [markdown]
# ## Your Info
# __Name:Dinh Nguyen
#
# __PDX Email:dinhn@pdx.edu
#
# __Collaborators:__

# %% [markdown]
# # Data Visualization Workout
#
# The following exercises will provide oppotunities to build simple plots using `pyplot`.

# %% [markdown]
# ## Workout 0 - Importing the Tools
#
# * Import the `pandas` library with the `pd` alias.
# * Import `numpy` with the `np` alias
# * Import `matplotlib.pyplot` with the `plt` alias.

# %%
## Begin Solution

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## End Solution

# %% [markdown]
# ## Workout 1 - Portland Oregon Home Price Index
#
# This workout uses a dataset based on the OR-Portland Home Price Index (POXRSA).
#
# The Home Price Index (HPI) is a broad measure of the movement of single-family house prices. It serves as a key indicator for understanding trends and changes in the housing market for a specific region – in this case, the Portland, Oregon metropolitan area. The POXRSA tracks the average change in housing prices over time, allowing us to observe periods of growth, decline, or stability.
#
# Source: [Fred | Economic Data](https://fred.stlouisfed.org/)
#
# __Some Background__
#
# Within the dataset, the `POXRSA` column represents an index value, not the actual dollar price of a home. Think of it as a standardized score that tracks the relative change in home prices in the Portland metropolitan area over time, with a specific point in the past serving as a baseline.
#
# * __Relative Change:__ The numbers in the `POXRSA` column tell you how home prices have changed relative to that baseline period.
#
#     * A value above 100 indicates that home prices in Portland were, on average, higher than during the baseline period.
#     * A value below 100 would indicate that home prices were, on average, lower than during the baseline period.
#     * A value of exactly 100 would represent the average home price during the baseline period.
#
# Let's see what information we can gather about Portland Housing Prices from this dataset.

# %% [markdown]
# ### Exercise 1 - Load the Data
#
# __Your Task:__
# 1. Load the dataset into a pandas dataframe, named `house_df`.
#     * File Path: `data/POXRSA.csv`
# 2. Display and Inspect Key Information about the dataframe

# %%
## Begin Solution

house_df = pd.read_csv('data/POXRSA.csv')

print(house_df.head(), house_df.info(), house_df.describe())

## End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  458 non-null    object
#  1   POXRSA            458 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.3+ KB
#   observation_date     POXRSA
# 0       1987-01-01  41.304891
# 1       1987-02-01  41.444215
# 2       1987-03-01  41.415249
# 3       1987-04-01  41.273786
# 4       1987-05-01  41.395046 None            POXRSA
# count  458.000000
# mean   149.242866
# std     81.726208
# min     41.273786
# 25%     86.745240
# 50%    134.983030
# 75%    185.425283
# max    337.307145

# %% [markdown]
# ### Exercise 2 - Transform the Data
#
# Once the data has been loaded and key information is displayed, notice the datatype of the `observation_date` values. The datatype is object.
#
# In order to best visualize this data, we must convert the `observation_date` values into datetime objects.
#
# __Your Task:__
# 1. Convert the `observation_date` column data type to datetime.
# 2. Display Key information about the dataframe to confirm the data type transformation.

# %%
## Begin Solution

house_df['observation_date'] = pd.to_datetime(house_df['observation_date'])

print(house_df.info())

## End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  458 non-null    datetime64[ns]
#  1   POXRSA            458 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.3 KB
# None

# %% [markdown]
# ### Exercise 3 - Plot the Data
#
# Next, let's present the data in a way that allows us to easily pick out any trends over time--a Line Graph.
#
# __Your Task__
# 1. Build a figure where:
#     * The figure size is 10 x 6
#     * The dpi is 100
# 2. Plot a Line Chart where:
#     * The x-axis is `observation_date`
#     * The y-axis is `POXRSA`
# 3. Customize the Chart:
#     * Set the title to "Housing Price Index - Portland Oregon"
#     * Set the x-label to "Year"
#     * Set the y-label to "Index"
#     * Add any additional customization that you see fit.

# %%
## Begin Solution

plt.figure(figsize=(10, 6), dpi=100)

plt.plot(house_df['observation_date'], house_df['POXRSA'])

plt.title('Housing Price Index - Portland Oregon')
plt.xlabel('Year')
plt.ylabel('Index')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

## End Solution

# %% [markdown]
# ### Reflect on the Data
#
# 1. What are the main patterns or trends you observe in your visualization? Describe what stands out to you.
#
# 2. Based on these patterns, what key insight or conclusion can you draw about the data? Explain your reasoning.
#
# 3. What is one question that your visualization raises for you about the data or the topic it represents?

# %% [markdown]
# __Begin Reflection__
#
# 1. Prices has been raising regardless of some fluctuations, it went back to raising pretty quickly afterward.
# 2. The key insight I can draw from this graph is that the housing price in Portland has significantly increased.
# 3. My question is that what made the price increase so much during the recent years comparing to before lets say 2005.
#
# __End Reflection__

# %% [markdown]
# ## Workout 2 - Egg Prices
#
# It seems that we just can't get a break at the grocery store. We see it on the news all the time, the price of eggs is way up. Let's take a look at this information for ourselves...

# %% [markdown]
# ### Exercise 1 - Load and Inspect the Data
#
# __Your Task:__
# 1. Load Average Price: Grade A Eggs dataset into a dataframe called `eggs_df`.
#     * File Path: `data/APU0000708111.csv`
# 2. Display key information to get an idea of what we are dealing with.

# %%
## Begin Solution

eggs_df = pd.read_csv('data/APU0000708111.csv')

print(eggs_df.head(), eggs_df.info(), eggs_df.describe())

## End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  543 non-null    object
#  1   APU0000708111     543 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.6+ KB
#   observation_date  APU0000708111
# 0       1980-01-01          0.879
# 1       1980-02-01          0.774
# 2       1980-03-01          0.812
# 3       1980-04-01          0.797
# 4       1980-05-01          0.737 None        APU0000708111
# count     543.000000
# mean        1.395899
# std         0.703229
# min         0.678000
# 25%         0.909500
# 50%         1.148000
# 75%         1.708500
# max         6.227000

# %% [markdown]
# ### Exercise 2 - Transform the Data
#
# __Your Task:__
# 1. Convert the `observation_date` column's datatype to datetime
# 2. Change the column names to something more fitting
# 3. Display key information to confirm transformations

# %%
## Begin Solution

print(eggs_df.columns)

eggs_df['observation_date'] = pd.to_datetime(eggs_df['observation_date'])

eggs_df.rename(columns={'APU0000708111': 'Average_Price'}, inplace=True)

print(eggs_df.info())


## End Solution
# Out:
# Index(['observation_date', 'APU0000708111'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  543 non-null    datetime64[ns]
#  1   Average_Price     543 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 8.6 KB
# None

# %% [markdown]
# ### Exercise 3 - Plot the Data
#
# A line graph will serve us well for visualizing and gathering insights on egg prices overtime. So let's build it.
#
# __Your Task:__
# 1. Build a figure where:
#     * The figure size is 10 x 6
#     * The dpi is 100
# 2. Plot a Line Chart where:
#     * The x-axis is based on the date.
#     * The y-axis is based on price.
# 3. Customize the Chart:
#     * Provide a Meaningful title
#     * Provide a Meaningful x-label
#     * Provide a Meaningful y-label
#     * Add any additional customization that you see fit.

# %%
## Begin Solution

plt.figure(figsize=(10, 6), dpi=100)

plt.plot(eggs_df['observation_date'], eggs_df['Average_Price'])

plt.title('Average Price of Grade A Eggs Over Time')
plt.xlabel('Year')
plt.ylabel('Average Price (USD)')
plt.grid(True)
plt.xticks(rotation=45)

plt.tight_layout()

## End Solution

# %% [markdown]
# ### Reflect on the Data
#
# 1. What are the main patterns or trends you observe in your visualization? Describe what stands out to you.
#
# 2. Based on these patterns, what key insight or conclusion can you draw about the data? Explain your reasoning.
#
# 3. What is one question that your visualization raises for you about the data or the topic it represents?

# %% [markdown]
# __Begin Reflection__
#
# 1. Egg prices were more consistent before 2005 regardless of fluctuations here and there. It went up a lot in the recent years.
# 2. Key insight from the graph is that prices startef to rise a lot after 2005 just like the housing prices.
# 3. My question is that is it because of inflation? or the industry has been degrading?
#
# __End Reflection__

# %% [markdown]
# ## Workout 3 Pet Data
#
# The next dataset that we will use  contains pet (dogs and cats) information across the United States.

# %% [markdown]
# ### Exercise 1: Load and Inspect the Data
#
# Alright you should be familiar with routine now.
#
# __Your Task__
#
# 1. Load the data into a dataframe called `pet_df`
#     * File Path: `data/catsvdogs.xlsx`
# 2. Inspect the data using the good ol' `df.info()` method.

# %%
## Begin Solution

pet_df = pd.read_excel('data/catsvdogs.xlsx')

print(pet_df.info())


## End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            49 non-null     object
#  1   Number of Households (in 1000)      49 non-null     int64
#  2   Percentage of households with pets  49 non-null     float64
#  3   Number of Pet Households (in 1000)  49 non-null     int64
#  4   Percentage of Dog Owners            49 non-null     float64
#  5   Dog Owning Households (1000s)       49 non-null     int64
#  6   Mean Number of Dogs per household   49 non-null     float64
#  7   Dog Population (in 1000)            49 non-null     int64
#  8   Percentage of Cat Owners            49 non-null     float64
#  9   Cat Owning Households               49 non-null     int64
#  10  Mean Number of Cats                 49 non-null     float64
#  11  Cat Population                      49 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 4.7+ KB
# None

# %% [markdown]
# ### Exercise 2 - Filter the Data
#
# For this particular exercise, let's focus on Oregon (perhaps we are biased for some reason).
#
# __Your Task__
# 1. Isolate the Oregon Row and place into a dataframe named `oregon`
# 2. Inspect the new dataframe

# %%
## Begin Solution

oregon = pet_df.loc[pet_df['Location'] == 'Oregon']

print(oregon.info())

## End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 35 to 35
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            1 non-null      object
#  1   Number of Households (in 1000)      1 non-null      int64
#  2   Percentage of households with pets  1 non-null      float64
#  3   Number of Pet Households (in 1000)  1 non-null      int64
#  4   Percentage of Dog Owners            1 non-null      float64
#  5   Dog Owning Households (1000s)       1 non-null      int64
#  6   Mean Number of Dogs per household   1 non-null      float64
#  7   Dog Population (in 1000)            1 non-null      int64
#  8   Percentage of Cat Owners            1 non-null      float64
#  9   Cat Owning Households               1 non-null      int64
#  10  Mean Number of Cats                 1 non-null      float64
#  11  Cat Population                      1 non-null      int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 104.0+ bytes
# None

# %% [markdown]
# ### Exercise 3 - Plot the Data (Pie Chart)
#
# Now let's create a pie chart to help use visualization the Cat and Dog Population in Oregon.
#
# __Your Task:__
# 1. Build a figure where:
#     * The figure size is 6 x 6
#     * The dpi is 100
# 2. Plot a Pie Chart with slices for:
#     * Dog Population
#     * Cat Population
# 4. Customize the Chart:
#     * Provide a meaningful title  for the chart
#     * Provide a meaningful labels for each slice
#     * Provide Contrasting Colors for each slice
#     * Provide a Legend
#     * Add any additional customization that you see fit.

# %%
## Begin Solution

plt.figure(figsize=(6, 6), dpi=100)

plt.pie([oregon['Dog Population (in 1000)'].values[0], oregon['Cat Population'].values[0]],
        labels=['Dog Population', 'Cat Population'],
        autopct='%1.1f%%',
        startangle=140,
        colors=['#ff9999','#66b3ff'])

plt.title('Pet Population in Oregon')
plt.legend(['Dog Population', 'Cat Population'])
plt.tight_layout()

# show dog population
print(f"Dog Population in Oregon: {oregon['Dog Population (in 1000)'].values[0]}")
# show cat population
print(f"Cat Population in Oregon: {oregon['Cat Population'].values[0]}")

## End Solution
# Out:
# Dog Population in Oregon: 917
# Cat Population in Oregon: 1185

# %% [markdown]
# ### Exercise 4 - Plot the Data (Number of Pet House Holds by Location)
#
# We haven't done a Bar Chart yet. The same dataset contains the Number of Pet Households by Location. Let's see what that looks like.
#
# __Your Task__
# 1. Build a figure where:
#     * The figure size is 12 x 6
#     * The dpi is 100
# 2. Plot a Bar Chart where:
#     * x-axis is the Location
#     * y-axis is the Number of Pet Households
# 4. Customize the Chart:
#     * Provide a meaningful title  for the chart
#     * Provide a meaningful labels
#     * Adjust the xticks for readability
#     * `rotation` and `fontsize` should be customized
#     * Add any additional customization that you see fit.

# %%
## Begin Solution

plt.figure(figsize=(12, 6), dpi=100)

plt.bar(pet_df['Location'], pet_df['Number of Pet Households (in 1000)'])

plt.title('Number of Pet Households by Location')
plt.xlabel('Location')
plt.ylabel('Number of Pet Households (in 1000)')
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y')

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()

## End Solution

# %% [markdown]
# ### Reflect on the Data
#
# 1. What are the main patterns or trends you observe in your visualization? Describe what stands out to you.
#
# 2. Based on these patterns, what key insight or conclusion can you draw about the data? Explain your reasoning.
#
# 3. What is one question that your visualization raises for you about the data or the topic it represents?

# %% [markdown]
# __Begin Reflection__
#
# 1. Main pattern or trends is that there are more pet households in bigger economic state like California, Florida compared to smaller ones.
# 2. Key insight that I can draw from this is that this data only shows us that the bigger population of a state, the more pets they have.
# 3. To effectively analyze the pet population across states, we should calculate the ratio of pet-owning households to the total number of households.
#
# __End Reflection__
